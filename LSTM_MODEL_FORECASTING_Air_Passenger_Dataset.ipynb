# %% [markdown]
# ### Airlines Passenger Forecasting using Stacked LSTM

# %% [markdown]
# This is a problem where, given a year and a month, the task is to predict the number of international airline passengers in units of 1,000. The data ranges from January 1949 to December 1960, or 12 years, with 144 observations.

# %%
import pandas as pd

# %%
df=pd.read_csv('AirPassengers.csv')

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.iloc[:,1])

# %% [markdown]
# ### Scaling
# LSTMs are sensitive to the scale of the input data, specifically when the sigmoid (default) or tanh activation functions are used. It can be a good practice to rescale the data to the range of 0-to-1, also called normalizing. We can easily normalize the dataset using the MinMaxScaler preprocessing class from the scikit-learn library.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df.iloc[:,1]
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: #Passengers, Length: 144, dtype: int64

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(df.iloc[:,1:])

# %%
df.shape
# Out:
# (144, 1)

# %%
df
# Out:
# array([[0.01544402],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853],
#        [0.05984556],
#        [0.08494208],
#        [0.08494208],
#        [0.06177606],
#        [0.02895753],
#        [0.        ],
#        [0.02702703],
#        [0.02123552],
#        [0.04247104],
#        [0.07142857],
#        [0.05984556],
#        [0.04054054],
#        [0.08687259],
#        [0.12741313],
#        [0.12741313],
#        [0.1042471 ],
#        [0.05598456],
#        [0.01930502],
#        [0.06949807],
#        [0.07915058],
#        [0.08880309],
#        [0.14285714],
#        [0.11389961],
#        [0.13127413],
#        [0.14285714],
#        [0.18339768],
#        [0.18339768],
#        [0.15444015],
#        [0.11196911],
#        [0.08108108],
#        [0.11969112],
#        [0.12934363],
#        [0.14671815],
#        [0.17181467],
#        [0.14864865],
#        [0.15250965],
#        [0.22007722],
#        [0.24324324],
#        [0.26640927],
#        [0.2027027 ],
#        [0.16795367],
#        [0.13127413],
#        [0.17374517],
#        [0.17760618],
#        [0.17760618],
#        [0.25482625],
#        [0.25289575],
#        [0.24131274],
#        [0.26833977],
#        [0.30888031],
#        [0.32432432],
#        [0.25675676],
#        [0.20656371],
#        [0.14671815],
#        [0.18725869],
#        [0.19305019],
#        [0.16216216],
#        [0.25289575],
#        [0.23745174],
#        [0.25096525],
#        [0.30888031],
#        [0.38223938],
#        [0.36486486],
#        [0.2992278 ],
#        [0.24131274],
#        [0.19111969],
#        [0.24131274],
#        [0.26640927],
#        [0.24903475],
#        [0.31467181],
#        [0.31853282],
#        [0.32046332],
#        [0.40733591],
#        [0.5019305 ],
#        [0.46911197],
#        [0.4015444 ],
#        [0.32818533],
#        [0.25675676],
#        [0.33590734],
#        [0.34749035],
#        [0.33397683],
#        [0.41119691],
#        [0.4034749 ],
#        [0.41312741],
#        [0.52123552],
#        [0.5965251 ],
#        [0.58108108],
#        [0.48455598],
#        [0.38996139],
#        [0.32239382],
#        [0.38996139],
#        [0.40733591],
#        [0.38030888],
#        [0.48648649],
#        [0.47104247],
#        [0.48455598],
#        [0.61389961],
#        [0.6969112 ],
#        [0.7007722 ],
#        [0.57915058],
#        [0.46911197],
#        [0.38803089],
#        [0.44787645],
#        [0.45559846],
#        [0.41312741],
#        [0.4980695 ],
#        [0.47104247],
#        [0.5       ],
#        [0.63899614],
#        [0.74710425],
#        [0.77413127],
#        [0.57915058],
#        [0.49227799],
#        [0.3976834 ],
#        [0.44980695],
#        [0.49420849],
#        [0.45945946],
#        [0.58301158],
#        [0.56370656],
#        [0.61003861],
#        [0.71042471],
#        [0.85714286],
#        [0.87837838],
#        [0.69305019],
#        [0.58494208],
#        [0.4980695 ],
#        [0.58108108],
#        [0.6042471 ],
#        [0.55405405],
#        [0.60810811],
#        [0.68918919],
#        [0.71042471],
#        [0.83204633],
#        [1.        ],
#        [0.96911197],
#        [0.77992278],
#        [0.68918919],
#        [0.55212355],
#        [0.63320463]])

# %%
##splitting dataset into train and test split
training_size=int(len(df)*0.65)

# %%
training_size
# Out:
# 93

# %%
test_size=len(df)-training_size

# %%
test_size
# Out:
# 51

# %%
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
test_data
# Out:
# array([[0.38996139],
#        [0.32239382],
#        [0.38996139],
#        [0.40733591],
#        [0.38030888],
#        [0.48648649],
#        [0.47104247],
#        [0.48455598],
#        [0.61389961],
#        [0.6969112 ],
#        [0.7007722 ],
#        [0.57915058],
#        [0.46911197],
#        [0.38803089],
#        [0.44787645],
#        [0.45559846],
#        [0.41312741],
#        [0.4980695 ],
#        [0.47104247],
#        [0.5       ],
#        [0.63899614],
#        [0.74710425],
#        [0.77413127],
#        [0.57915058],
#        [0.49227799],
#        [0.3976834 ],
#        [0.44980695],
#        [0.49420849],
#        [0.45945946],
#        [0.58301158],
#        [0.56370656],
#        [0.61003861],
#        [0.71042471],
#        [0.85714286],
#        [0.87837838],
#        [0.69305019],
#        [0.58494208],
#        [0.4980695 ],
#        [0.58108108],
#        [0.6042471 ],
#        [0.55405405],
#        [0.60810811],
#        [0.68918919],
#        [0.71042471],
#        [0.83204633],
#        [1.        ],
#        [0.96911197],
#        [0.77992278],
#        [0.68918919],
#        [0.55212355],
#        [0.63320463]])

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 4
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
X_train.shape, y_train.shape
# Out:
# ((88, 4), (88,))

# %%
import numpy as np
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0], 4, 1)
X_test = X_test.reshape(X_test.shape[0], 4, 1)

# %%
X_train.shape
# Out:
# (88, 4, 1)

# %%
### Create the LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(4,1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=1,verbose=1)
# Out:
# Epoch 1/100
# 88/88 [==============================] - 3s 10ms/step - loss: 0.0162 - val_loss: 0.0481
# Epoch 2/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0278
# Epoch 3/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0278
# Epoch 4/100
# 88/88 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0253
# Epoch 5/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0338
# Epoch 6/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0236
# Epoch 7/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0341
# Epoch 8/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0269
# Epoch 9/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0231
# Epoch 10/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0269
# Epoch 11/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0212
# Epoch 12/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0265
# Epoch 13/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0229
# Epoch 14/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0227
# Epoch 15/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0169
# Epoch 16/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0152
# Epoch 17/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0140
# Epoch 18/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0138
# Epoch 19/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0115
# Epoch 20/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0234
# Epoch 21/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0103
# Epoch 22/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0075
# Epoch 23/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0091
# Epoch 24/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0073
# Epoch 25/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0083
# Epoch 26/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0090
# Epoch 27/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0078
# Epoch 28/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0079
# Epoch 29/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0167
# Epoch 30/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0101
# Epoch 31/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0088
# Epoch 32/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0083
# Epoch 33/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0134
# Epoch 34/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0098
# Epoch 35/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0088
# Epoch 36/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0093
# Epoch 37/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0087
# Epoch 38/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0099
# Epoch 39/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0125
# Epoch 40/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0091
# Epoch 41/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0091
# Epoch 42/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0109
# Epoch 43/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0115
# Epoch 44/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0197
# Epoch 45/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0143
# Epoch 46/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 47/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0077
# Epoch 48/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0124
# Epoch 49/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0107
# Epoch 50/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0166
# Epoch 51/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0076
# Epoch 52/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 53/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0100
# Epoch 54/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0076
# Epoch 55/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0147
# Epoch 56/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0116
# Epoch 57/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 58/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0153
# Epoch 59/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0163
# Epoch 60/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0115
# Epoch 61/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0219
# Epoch 62/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0148
# Epoch 63/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0154
# Epoch 64/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0148
# Epoch 65/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0128
# Epoch 66/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0348
# Epoch 67/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0084
# Epoch 68/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0227
# Epoch 69/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0123
# Epoch 70/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0244
# Epoch 71/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0125
# Epoch 72/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0142
# Epoch 73/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0503
# Epoch 74/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0230
# Epoch 75/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0109
# Epoch 76/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0288
# Epoch 77/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0407
# Epoch 78/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0133
# Epoch 79/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0116
# Epoch 80/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0179
# Epoch 81/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0099
# Epoch 82/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0074
# Epoch 83/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0214
# Epoch 84/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0131
# Epoch 85/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0169
# Epoch 86/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0122
# Epoch 87/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0163
# Epoch 88/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0174
# Epoch 89/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0137
# Epoch 90/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0143
# Epoch 91/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0273
# Epoch 92/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0138
# Epoch 93/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0135
# Epoch 94/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0250
# Epoch 95/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0106
# Epoch 96/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0164
# Epoch 97/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0143
# Epoch 98/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0117
# Epoch 99/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0387
# Epoch 100/100
# 88/88 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0171

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 3/3 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 0s 17ms/step

# %%
test_predict
# Out:
# array([[0.39255613],
#        [0.3718034 ],
#        [0.56157845],
#        [0.40399057],
#        [0.51545835],
#        [0.68818927],
#        [0.64763385],
#        [0.62875104],
#        [0.40612495],
#        [0.39417648],
#        [0.33023694],
#        [0.4983796 ],
#        [0.41961884],
#        [0.39309484],
#        [0.5689333 ],
#        [0.39498955],
#        [0.5427505 ],
#        [0.7093    ],
#        [0.7109941 ],
#        [0.68818015],
#        [0.28827488],
#        [0.48750746],
#        [0.2788574 ],
#        [0.50373876],
#        [0.47922564],
#        [0.41869837],
#        [0.69044155],
#        [0.43171138],
#        [0.67456573],
#        [0.7040065 ],
#        [0.8562901 ],
#        [0.61993194],
#        [0.3395338 ],
#        [0.4645067 ],
#        [0.2980792 ],
#        [0.62638533],
#        [0.4954365 ],
#        [0.48664218],
#        [0.6546249 ],
#        [0.64299804],
#        [0.6072543 ],
#        [0.888351  ],
#        [0.8663789 ],
#        [0.4490816 ],
#        [0.3590262 ],
#        [0.39760154]], dtype=float32)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
test_predict
# Out:
# array([[307.3441 ],
#        [296.59418],
#        [394.89764],
#        [313.26712],
#        [371.00745],
#        [460.48206],
#        [439.47433],
#        [429.69305],
#        [314.37274],
#        [308.18344],
#        [275.06274],
#        [362.16064],
#        [321.36258],
#        [307.62314],
#        [398.70746],
#        [308.6046 ],
#        [385.14478],
#        [471.4174 ],
#        [472.29498],
#        [460.47733],
#        [253.32639],
#        [356.52887],
#        [248.44814],
#        [364.93668],
#        [352.2389 ],
#        [320.88577],
#        [461.64874],
#        [327.6265 ],
#        [453.42505],
#        [468.67538],
#        [547.5582 ],
#        [425.12476],
#        [279.8785 ],
#        [344.61447],
#        [258.40503],
#        [428.46762],
#        [360.6361 ],
#        [356.08066],
#        [443.0957 ],
#        [437.073  ],
#        [418.55774],
#        [564.16583],
#        [552.78424],
#        [336.62427],
#        [289.9756 ],
#        [309.9576 ]], dtype=float32)

# %%
y_train.shape,train_predict.shape,train_predict
# Out:
# ((88,),
#  (88, 1),
#  array([[129.28564 ],
#         [123.70778 ],
#         [136.51079 ],
#         [147.66959 ],
#         [148.10187 ],
#         [138.95905 ],
#         [124.86414 ],
#         [111.06015 ],
#         [120.20215 ],
#         [116.25926 ],
#         [125.543526],
#         [139.93202 ],
#         [135.37665 ],
#         [128.37772 ],
#         [150.53044 ],
#         [168.92668 ],
#         [169.00719 ],
#         [160.56169 ],
#         [139.12634 ],
#         [122.50298 ],
#         [142.94315 ],
#         [144.57127 ],
#         [150.05988 ],
#         [179.05621 ],
#         [162.2547  ],
#         [176.17273 ],
#         [181.1717  ],
#         [202.47433 ],
#         [199.48532 ],
#         [186.35255 ],
#         [167.67084 ],
#         [153.78484 ],
#         [172.00897 ],
#         [172.2604  ],
#         [181.85507 ],
#         [195.79288 ],
#         [181.94872 ],
#         [188.45572 ],
#         [225.57872 ],
#         [229.91777 ],
#         [246.02402 ],
#         [204.79907 ],
#         [199.50632 ],
#         [179.39519 ],
#         [203.19206 ],
#         [197.58446 ],
#         [199.04565 ],
#         [245.95369 ],
#         [231.55406 ],
#         [232.33699 ],
#         [252.62398 ],
#         [271.59222 ],
#         [274.12097 ],
#         [229.60184 ],
#         [218.47581 ],
#         [186.64182 ],
#         [213.84187 ],
#         [206.41188 ],
#         [189.68452 ],
#         [248.35385 ],
#         [221.47209 ],
#         [241.04668 ],
#         [275.38058 ],
#         [312.40115 ],
#         [282.40765 ],
#         [254.9889  ],
#         [233.67839 ],
#         [209.67111 ],
#         [244.6255  ],
#         [244.9574  ],
#         [232.80551 ],
#         [283.0815  ],
#         [265.64215 ],
#         [275.2968  ],
#         [337.86856 ],
#         [376.60797 ],
#         [318.538   ],
#         [306.0613  ],
#         [266.75052 ],
#         [236.88782 ],
#         [306.0887  ],
#         [278.41766 ],
#         [278.52026 ],
#         [341.2032  ],
#         [298.38562 ],
#         [328.2755  ],
#         [405.97568 ],
#         [407.11206 ]], dtype=float32))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 224.07657802978665

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 385.17056963879946

# %%
### Plotting 
# shift train predictions for plotting
look_back=4
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
